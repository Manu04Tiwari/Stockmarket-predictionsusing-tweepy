# %%
pip install tweepy
# Out:
# Requirement already satisfied: tweepy in c:\users\praab\appdata\local\programs\python\python312\lib\site-packages (4.14.0)
# Requirement already satisfied: oauthlib<4,>=3.2.0 in c:\users\praab\appdata\local\programs\python\python312\lib\site-packages (from tweepy) (3.2.2)
# Requirement already satisfied: requests<3,>=2.27.0 in c:\users\praab\appdata\local\programs\python\python312\lib\site-packages (from tweepy) (2.32.3)
# Requirement already satisfied: requests-oauthlib<2,>=1.2.0 in c:\users\praab\appdata\local\programs\python\python312\lib\site-packages (from tweepy) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\praab\appdata\local\programs\python\python312\lib\site-packages (from requests<3,>=2.27.0->tweepy) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\praab\appdata\local\programs\python\python312\lib\site-packages (from requests<3,>=2.27.0->tweepy) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\praab\appdata\local\programs\python\python312\lib\site-packages (from requests<3,>=2.27.0->tweepy) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\praab\appdata\local\programs\python\python312\lib\site-packages (from requests<3,>=2.27.0->tweepy) (2024.8.30)
# Note: you may need to restart the kernel to use updated packages.

# %%
import tweepy
import csv

# Twitter API credentials
consumer_key = 'your_consumer_key'
consumer_secret = 'your_consumer_secret'
access_token = 'your_access_token'
access_token_secret = 'your_access_token_secret'

# Authenticate to Twitter
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)

# Create API object
api = tweepy.API(auth, wait_on_rate_limit=True)

# Define your search parameters
search_query = 'AAPL'
tweet_count = 100

# Fetch tweets
tweets = tweepy.Cursor(api.search_tweets, q=search_query, tweet_mode='extended', lang='en').items(tweet_count)

# Create a CSV file to save the tweets
csv_file = open('aapl_tweets.csv', 'w', newline='', encoding='utf-8')
csv_writer = csv.writer(csv_file)
csv_writer.writerow(['Tweet', 'Username', 'Date'])

# Process the tweets and save them to the CSV file
for tweet in tweets:
    tweet_text = tweet.full_text
    username = tweet.user.screen_name
    date = tweet.created_at
    csv_writer.writerow([tweet_text, username, date])

# Close the CSV file
csv_file.close()
# Out:
# c:\Users\Praab\AppData\Local\Programs\Python\Python312\Lib\site-packages\tweepy\api.py:301: SyntaxWarning: invalid escape sequence '\['
#   """home_timeline(*, count, since_id, max_id, trim_user, \
# c:\Users\Praab\AppData\Local\Programs\Python\Python312\Lib\site-packages\tweepy\api.py:341: SyntaxWarning: invalid escape sequence '\['
#   """mentions_timeline(*, count, since_id, max_id, trim_user, \
# c:\Users\Praab\AppData\Local\Programs\Python\Python312\Lib\site-packages\tweepy\api.py:376: SyntaxWarning: invalid escape sequence '\['
#   """user_timeline(*, user_id, screen_name, since_id, count, max_id, \
# c:\Users\Praab\AppData\Local\Programs\Python\Python312\Lib\site-packages\tweepy\api.py:426: SyntaxWarning: invalid escape sequence '\['
#   """get_favorites(*, user_id, screen_name, count, since_id, max_id, \
# c:\Users\Praab\AppData\Local\Programs\Python\Python312\Lib\site-packages\tweepy\api.py:467: SyntaxWarning: invalid escape sequence '\['
#   """lookup_statuses(id, *, include_entities, trim_user, map, \
# c:\Users\Praab\AppData\Local\Programs\Python\Python312\Lib\site-packages\tweepy\api.py:599: SyntaxWarning: invalid escape sequence '\['
#   """get_retweeter_ids(id, *, count, cursor, stringify_ids)
# c:\Users\Praab\AppData\Local\Programs\Python\Python312\Lib\site-packages\tweepy\api.py:634: SyntaxWarning: invalid escape sequence '\['
#   """get_retweets(id, *, count, trim_user)
# c:\Users\Praab\AppData\Local\Programs\Python\Python312\Lib\site-packages\tweepy\api.py:667: SyntaxWarning: invalid escape sequence '\['
#   """get_retweets_of_me(*, count, since_id, max_id, trim_user, \
# c:\Users\Praab\AppData\Local\Programs\Python\Python312\Lib\site-packages\tweepy\api.py:1055: SyntaxWarning: invalid escape sequence '\ '
#   """search_tweets(q, *, geocode, lang, locale, result_type, count, \
# c:\Users\Praab\AppData\Local\Programs\Python\Python312\Lib\site-packages\tweepy\api.py:1157: SyntaxWarning: invalid escape sequence '\['
#   """get_lists(*, user_id, screen_name, reverse)
# c:\Users\Praab\AppData\Local\Programs\Python\Python312\Lib\site-packages\tweepy\api.py:1202: SyntaxWarning: invalid escape sequence '\['
#   """get_list_members(*, list_id, slug, owner_screen_name, owner_id, \
# c:\Users\Praab\AppData\Local\Programs\Python\Python312\Lib\site-packages\tweepy\api.py:1299: SyntaxWarning: invalid escape sequence '\['
#   """get_list_memberships(*, user_id, screen_name, count, cursor, \
# c:\Users\Praab\AppData\Local\Programs\Python\Python312\Lib\site-packages\tweepy\api.py:1342: SyntaxWarning: invalid escape sequence '\['
#   """get_list_ownerships(*, user_id, screen_name, count, cursor)
# c:\Users\Praab\AppData\Local\Programs\Python\Python312\Lib\site-packages\tweepy\api.py:1409: SyntaxWarning: invalid escape sequence '\['
#   """list_timeline( \
# c:\Users\Praab\AppData\Local\Programs\Python\Python312\Lib\site-packages\tweepy\api.py:1460: SyntaxWarning: invalid escape sequence '\['
#   """get_list_subscribers( \
# c:\Users\Praab\AppData\Local\Programs\Python\Python312\Lib\site-packages\tweepy\api.py:1559: SyntaxWarning: invalid escape sequence '\['
#   """get_list_subscriptions(*, user_id, screen_name, count, cursor)
# c:\Users\Praab\AppData\Local\Programs\Python\Python312\Lib\site-packages\tweepy\api.py:1927: SyntaxWarning: invalid escape sequence '\['
#   """get_follower_ids(*, user_id, screen_name, cursor, stringify_ids, \
# c:\Users\Praab\AppData\Local\Programs\Python\Python312\Lib\site-packages\tweepy\api.py:1966: SyntaxWarning: invalid escape sequence '\['
#   """get_followers(*, user_id, screen_name, cursor, count, skip_status, \
# c:\Users\Praab\AppData\Local\Programs\Python\Python312\Lib\site-packages\tweepy\api.py:2008: SyntaxWarning: invalid escape sequence '\['
#   """get_friend_ids(*, user_id, screen_name, cursor, stringify_ids, \
# c:\Users\Praab\AppData\Local\Programs\Python\Python312\Lib\site-packages\tweepy\api.py:2047: SyntaxWarning: invalid escape sequence '\['
#   """get_friends(*, user_id, screen_name, cursor, count, skip_status, \
# c:\Users\Praab\AppData\Local\Programs\Python\Python312\Lib\site-packages\tweepy\api.py:2089: SyntaxWarning: invalid escape sequence '\['
#   """incoming_friendships(*, cursor, stringify_ids)
# c:\Users\Praab\AppData\Local\Programs\Python\Python312\Lib\site-packages\tweepy\api.py:2120: SyntaxWarning: invalid escape sequence '\['
#   """lookup_friendships(*, screen_name, user_id)
# c:\Users\Praab\AppData\Local\Programs\Python\Python312\Lib\site-packages\tweepy\api.py:2149: SyntaxWarning: invalid escape sequence '\['
#   """no_retweets_friendships(*, stringify_ids)
# c:\Users\Praab\AppData\Local\Programs\Python\Python312\Lib\site-packages\tweepy\api.py:2176: SyntaxWarning: invalid escape sequence '\['
#   """outgoing_friendships(*, cursor, stringify_ids)
# c:\Users\Praab\AppData\Local\Programs\Python\Python312\Lib\site-packages\tweepy\api.py:2243: SyntaxWarning: invalid escape sequence '\['
#   """lookup_users(*, screen_name, user_id, include_entities, tweet_mode)
# c:\Users\Praab\AppData\Local\Programs\Python\Python312\Lib\site-packages\tweepy\api.py:2290: SyntaxWarning: invalid escape sequence '\['
#   """search_users(q, *, page, count, include_entities)
# c:\Users\Praab\AppData\Local\Programs\Python\Python312\Lib\site-packages\tweepy\api.py:2500: SyntaxWarning: invalid escape sequence '\['
#   """get_saved_searches()
# c:\Users\Praab\AppData\Local\Programs\Python\Python312\Lib\site-packages\tweepy\api.py:2814: SyntaxWarning: invalid escape sequence '\['
#   """get_blocked_ids(*, stringify_ids, cursor)
# c:\Users\Praab\AppData\Local\Programs\Python\Python312\Lib\site-packages\tweepy\api.py:2846: SyntaxWarning: invalid escape sequence '\['
#   """get_blocks(*, include_entities, skip_status, cursor)
# c:\Users\Praab\AppData\Local\Programs\Python\Python312\Lib\site-packages\tweepy\api.py:2880: SyntaxWarning: invalid escape sequence '\['
#   """get_muted_ids(*, stringify_ids, cursor)
# c:\Users\Praab\AppData\Local\Programs\Python\Python312\Lib\site-packages\tweepy\api.py:2911: SyntaxWarning: invalid escape sequence '\['
#   """get_mutes(*, cursor, include_entities, skip_status)
# c:\Users\Praab\AppData\Local\Programs\Python\Python312\Lib\site-packages\tweepy\api.py:3126: SyntaxWarning: invalid escape sequence '\['
#   """get_direct_messages(*, count, cursor)
# c:\Users\Praab\AppData\Local\Programs\Python\Python312\Lib\site-packages\tweepy\api.py:3788: SyntaxWarning: invalid escape sequence '\['
#   """reverse_geocode(lat, long, *, accuracy, granularity, max_results)
# c:\Users\Praab\AppData\Local\Programs\Python\Python312\Lib\site-packages\tweepy\api.py:3829: SyntaxWarning: invalid escape sequence '\['
#   """search_geo(*, lat, long, query, ip, granularity, max_results)
# ---------------------------------------------------------------------------
# Unauthorized                              Traceback (most recent call last)
# Cell In[2], line 30
#      27 csv_writer.writerow(['Tweet', 'Username', 'Date'])
#      29 # Process the tweets and save them to the CSV file
# ---> 30 for tweet in tweets:
#      31     tweet_text = tweet.full_text
#      32     username = tweet.user.screen_name
#
# File c:\Users\Praab\AppData\Local\Programs\Python\Python312\Lib\site-packages\tweepy\cursor.py:86, in BaseIterator.__next__(self)
#      85 def __next__(self):
# ---> 86     return self.next()
#
# File c:\Users\Praab\AppData\Local\Programs\Python\Python312\Lib\site-packages\tweepy\cursor.py:286, in ItemIterator.next(self)
#     283     raise StopIteration
#     284 if self.current_page is None or self.page_index == len(self.current_page) - 1:
#     285     # Reached end of current page, get the next page...
# --> 286     self.current_page = next(self.page_iterator)
#     287     while len(self.current_page) == 0:
#     288         self.current_page = next(self.page_iterator)
#
# File c:\Users\Praab\AppData\Local\Programs\Python\Python312\Lib\site-packages\tweepy\cursor.py:86, in BaseIterator.__next__(self)
#      85 def __next__(self):
# ---> 86     return self.next()
#
# File c:\Users\Praab\AppData\Local\Programs\Python\Python312\Lib\site-packages\tweepy\cursor.py:167, in IdIterator.next(self)
#     164     raise StopIteration
#     166 if self.index >= len(self.results) - 1:
# --> 167     data = self.method(max_id=self.max_id, parser=RawParser(), *self.args, **self.kwargs)
#     169     model = ModelParser().parse(
#     170         data, api = self.method.__self__,
#     171         payload_list=self.method.payload_list,
#     172         payload_type=self.method.payload_type
#     173     )
#     174     result = self.method.__self__.parser.parse(
#     175         data, api = self.method.__self__,
#     176         payload_list=self.method.payload_list,
#     177         payload_type=self.method.payload_type
#     178     )
#
# File c:\Users\Praab\AppData\Local\Programs\Python\Python312\Lib\site-packages\tweepy\api.py:33, in pagination.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#      31 @functools.wraps(method)
#      32 def wrapper(*args, **kwargs):
# ---> 33     return method(*args, **kwargs)
#
# File c:\Users\Praab\AppData\Local\Programs\Python\Python312\Lib\site-packages\tweepy\api.py:46, in payload.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#      44 kwargs['payload_list'] = payload_list
#      45 kwargs['payload_type'] = payload_type
# ---> 46 return method(*args, **kwargs)
#
# File c:\Users\Praab\AppData\Local\Programs\Python\Python312\Lib\site-packages\tweepy\api.py:1146, in API.search_tweets(self, q, **kwargs)
#    1052 @pagination(mode='id')
#    1053 @payload('search_results')
#    1054 def search_tweets(self, q, **kwargs):
#    1055     """search_tweets(q, *, geocode, lang, locale, result_type, count, \
#    1056                      until, since_id, max_id, include_entities)
#    1057
#    (...)
#    1144     .. _Twitter's documentation on the standard search API: https://developer.twitter.com/en/docs/twitter-api/v1/tweets/search/overview
#    1145     """
# -> 1146     return self.request(
#    1147         'GET', 'search/tweets', endpoint_parameters=(
#    1148             'q', 'geocode', 'lang', 'locale', 'result_type', 'count',
#    1149             'until', 'since_id', 'max_id', 'include_entities'
#    1150         ), q=q, **kwargs
#    1151     )
#
# File c:\Users\Praab\AppData\Local\Programs\Python\Python312\Lib\site-packages\tweepy\api.py:269, in API.request(self, method, endpoint, endpoint_parameters, params, headers, json_payload, parser, payload_list, payload_type, post_data, files, require_auth, return_cursors, upload_api, use_cache, **kwargs)
#     267     raise BadRequest(resp)
#     268 if resp.status_code == 401:
# --> 269     raise Unauthorized(resp)
#     270 if resp.status_code == 403:
#     271     raise Forbidden(resp)
#
# Unauthorized: 401 Unauthorized
# 89 - Invalid or expired token.
